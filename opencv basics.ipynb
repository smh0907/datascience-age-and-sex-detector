# %%
import cv2
from matplotlib import pyplot as plt

# %%
img1=cv2.imread("data\me.jpg")

# %%
plt.imshow(img1)

# %%
img2=cv2.imread("data\me2.jpg")
plt.imshow(img2)

# %% [markdown]
# # addition

# %%
img2=cv2.imread("data\me2.jpg")

# %%
img2_resized = cv2.resize(img2, (img1.shape[1], img1.shape[0]))

# %%
result = img1 + img2_resized

# %%
plt.imshow(result)
